# %% [markdown]
# # 03b — Observability & Reliability Tradeoffs
#
# Timebox: 45 minutes
#
# Answer using bullet sections: SLOs, failure taxonomy, instrumentation, guardrails, rollback, cost-aware scaling.
#
# Prompts:
# 1) Define SLIs/SLOs for an agentic workflow using tools (e.g., calculator, web). Include success, latency, tool error rate, and safety incidents.
# 2) Propose logging/metrics/tracing schema to support postmortems and continuous eval. Include eval event schema and dashboards.
# 3) Design rollback and kill-switch mechanisms for degraded behavior. Explain thresholds and alerts.
