# %% [markdown]
# # 03a — LLM System Design Prompts
#
# Timebox: 45 minutes
#
# Answer in structured sections: requirements, architecture, data/eval, rollout, observability, cost.
#
# Prompts:
# 1) Design an offline+online LLM evaluation service for multiple teams. Include: data schema for eval events, batch scorers, online guardrails, and dashboards. Address latency/cost.
# 2) Plan a staged rollout for a new agent policy: shadowing, A/B, guardrail thresholds, rollback triggers, and change management.
